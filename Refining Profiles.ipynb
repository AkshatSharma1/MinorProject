# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import _pickle as pickle
import numpy as np
from scipy.stats import halfnorm

# %%
with open("ProfileData_pickleFiles/profile_data.pkl",'rb') as fp:
    df = pickle.load(fp)

# %%
df
# Out:
#                                                    Bios  Movies  TV  Religion  \
# 0     Typical communicator. Subtly charming web advo...       0   6         4
# 1     Introvert. Friendly beer guru. Bacon fanatic. ...       0   3         5
# 2     Friend of animals everywhere. Passionate zombi...       2   5         6
# 3     Webaholic. Pop culture ninja. Wannabe organize...       4   2         9
# 4     Zombie buff. Troublemaker. Social media ninja....       3   0         9
# ...                                                 ...     ...  ..       ...
# 8290  Wannabe analyst. General food enthusiast. Musi...       1   2         1
# 8291  Friendly pop cultureaholic. Analyst. Gamer. Am...       1   4         8
# 8292  Alcohol nerd. Award-winning music fan. Profess...       2   6         3
# 8293  Organizer. Introvert. Twitter junkie. Certifie...       1   8         2
# 8294  Unable to type with boxing gloves on. Devoted ...       0   7         4
#
#       Music  Sports  Travelling  Foodie  Books  Politics  Finance  Coding
# 0         2       2           2       5      2         3        5       5
# 1         5       7           3       7      5         4        2       0
# 2         4       3           0       3      1         8        7       8
# 3         6       9           5       0      5         1        5       2
# 4         6       7           1       0      2         3        5       6
# ...     ...     ...         ...     ...    ...       ...      ...     ...
# 8290      1       1           5       6      2         7        2       9
# 8291      2       8           5       5      3         1        5       1
# 8292      0       0           2       7      1         1        9       0
# 8293      2       9           6       1      8         7        0       8
# 8294      3       4           7       2      7         3        0       4
#
# [8295 rows x 12 columns]

# %%
# Using only Bios
# Removing the numerical data
df = df[['Bios']]

# %%
df
# Out:
#                                                    Bios
# 0     Typical communicator. Subtly charming web advo...
# 1     Introvert. Friendly beer guru. Bacon fanatic. ...
# 2     Friend of animals everywhere. Passionate zombi...
# 3     Webaholic. Pop culture ninja. Wannabe organize...
# 4     Zombie buff. Troublemaker. Social media ninja....
# ...                                                 ...
# 8290  Wannabe analyst. General food enthusiast. Musi...
# 8291  Friendly pop cultureaholic. Analyst. Gamer. Am...
# 8292  Alcohol nerd. Award-winning music fan. Profess...
# 8293  Organizer. Introvert. Twitter junkie. Certifie...
# 8294  Unable to type with boxing gloves on. Devoted ...
#
# [8295 rows x 1 columns]

# %% [markdown]
# ### Creating Lists for the Categories
# Here, we are specifying the categories into subcategories and allocating the probability of being an interest to each subcategory of interest

# %%
#Probability distribution
p = {}

# TV Genres
tv = ['Comedy',
      'Drama',
      'Action/Adventure',
      'Suspense/Thriller',
      'Documentaries',
      'Crime/Mystery',
      'News',
      'SciFi',
      'History']

p['TV'] = [0.25,
           0.21,
           0.17,
           0.16,
           0.09,
           0.08,
           0.03,
           0.02,
           0.01]

# Movie Genres
movies = ['Adventure',
          'Action',
          'Drama',
          'Comedy',
          'Thriller',
          'Horror',
          'RomCom',
          'Musical',
          'Documentary']

p['Movies'] = [0.26,
               0.21,
               0.16,
               0.14,
               0.09,
               0.06,
               0.04,
               0.01, 
               0.03]

# Religions (could potentially create a spectrum)
religion = ['Catholic',
            'Christian',
            'Jewish',
            'Muslim',
            'Hindu',
            'Buddhist',
            'Spiritual',
            'Other',
            'Agnostic',
            'Atheist']

p['Religion'] = [0.07,
                 0.13,
                 0.01,
                 0.19,
                 0.24,
                 0.05,
                 0.10,
                 0.09,
                 0.07,
                 0.05]

# Music
music = ['Rock',
         'HipHop',
         'Romantic',
         'Pop',
         'Country',
         'EDM',
         'Jazz',
         'Classical',
         ]

p['Music'] = [0.25,
              0.19,
              0.16,
              0.14,
              0.10,
              0.06,
              0.04,
              0.03,
              0.02,
              0.01,]

# Sports
sports = [
          'Cricket',
          'Chess',
          'Badminton'
          'Football',
          'Baseball',
          'Basketball',
          'Hockey',
          'Soccer',
          'Other']

p['Sports'] = [0.29,
               0.24,
               0.23, 
               0.13,
               0.04,
               0.03,
               0.02,
               0.02]

# Politics (could also put on a spectrum)
politics = ['Liberal',
            'Progressive',
            'Centrist',
            'Moderate',
            'Conservative']

p['Politics'] = [0.26,
                 0.11,
                 0.11,
                 0.15,
                 0.37]

# Social Media
social = ['Facebook',
          'Youtube',
          'Twitter',
          'Reddit',
          'Instagram',
          'Pinterest',
          'LinkedIn',
          'SnapChat',
          'TikTok']

p['Social Media'] = [0.36,
                     0.27,
                     0.11,
                     0.09,
                     0.05,
                     0.03,
                     0.03,
                     0.03,
                     0.03]

# Programming
programming = [
          'Python',
          'Java',
          'JavaScript',
          'C++',
          'C#',
          'Swift',
          'Go'
         ]

p['programming'] = [
                    0.23,
                    0.20,
                    0.18,
                    0.15,
                    0.12,
                    0.10,
                    0.02
                   ]

#travelling
travelling = [
            'Treking',
            'Adventure',
            'Long Trips',
            'Short journeys'
             ]

p['travelling'] = [
                 0.35,
                 0.33,
                 0.21,
                 0.11
                  ]


# Age (generating random numbers based on half normal distribution)
age = halfnorm.rvs(loc=18,scale=8, size=df.shape[0]).astype(int)

# Lists of Names and the list of the lists
categories = [movies, religion, music, politics, social, sports,programming, travelling, age]

names = ['Movies','Religion', 'Music', 'Politics', 'Social Media', 'Sports', 'Programming', 'Traveller', 'Age']

combined = dict(zip(names, categories))

# %%
combined
# Out:
# {'Movies': ['Adventure',
#   'Action',
#   'Drama',
#   'Comedy',
#   'Thriller',
#   'Horror',
#   'RomCom',
#   'Musical',
#   'Documentary'],
#  'Religion': ['Catholic',
#   'Christian',
#   'Jewish',
#   'Muslim',
#   'Hindu',
#   'Buddhist',
#   'Spiritual',
#   'Other',
#   'Agnostic',
#   'Atheist'],
#  'Music': ['Rock',
#   'HipHop',
#   'Romantic',
#   'Pop',
#   'Country',
#   'EDM',
#   'Jazz',
#   'Classical'],
#  'Politics': ['Liberal',
#   'Progressive',
#   'Centrist',
#   'Moderate',
#   'Conservative'],
#  'Social Media': ['Facebook',
#   'Youtube',
#   'Twitter',
#   'Reddit',
#   'Instagram',
#   'Pinterest',
#   'LinkedIn',
#   'SnapChat',
#   'TikTok'],
#  'Sports': ['Cricket',
#   'Chess',
#   'BadmintonFootball',
#   'Baseball',
#   'Basketball',
#   'Hockey',
#   'Soccer',
#   'Other'],
#  'Programming': ['Python', 'Java', 'JavaScript', 'C++', 'C#', 'Swift', 'Go'],
#  'Traveller': ['Treking', 'Adventure', 'Long Trips', 'Short journeys'],
#  'Age': array([19, 19, 23, ..., 34, 24, 38])}

# %% [markdown]
# ### Assigning random values to each subcategory of a category
# Looping through the combined df, we will assign randomly generated value from each subcategory to the repsective category

# %%
# Looping through and assigning random values
for name, ops in combined.items():
    if name in ['Religion', 'Politics']:
        # Picking only 1 from the list
        df[name] = np.random.choice(ops, df.shape[0], p=p[name])
        
    elif name == 'Age':
        # Generating random ages based on a normal distribution
        df[name] = ops
    else:
        # Picking 3 from the list 
        try:
            df[name] = list(np.random.choice(ops, size=(df.shape[0],1,3), p=p[name]))
        except:
            df[name] = list(np.random.choice(ops, size=(df.shape[0],1,3)))
        
        df[name] = df[name].apply(lambda x: list(set(x[0].tolist())))
# Out:
# C:\Users\aksha\AppData\Local\Temp/ipykernel_10020/1128398756.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[name] = list(np.random.choice(ops, size=(df.shape[0],1,3), p=p[name]))
# C:\Users\aksha\AppData\Local\Temp/ipykernel_10020/1128398756.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[name] = df[name].apply(lambda x: list(set(x[0].tolist())))
# C:\Users\aksha\AppData\Local\Temp/ipykernel_10020/1128398756.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[name] = np.random.choice(ops, df.shape[0], p=p[name])
# C:\Users\aksha\AppData\Local\Temp/ipykernel_10020/1128398756.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[name] = list(np.random.choice(ops, size=(df.shape[0],1,3)))
# C:\Users\aksha\AppData\Local\Temp/ipykernel_10020/1128398756.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[name] = ops

# %%
df
# Out:
#                                                    Bios  \
# 0     Typical communicator. Subtly charming web advo...
# 1     Introvert. Friendly beer guru. Bacon fanatic. ...
# 2     Friend of animals everywhere. Passionate zombi...
# 3     Webaholic. Pop culture ninja. Wannabe organize...
# 4     Zombie buff. Troublemaker. Social media ninja....
# ...                                                 ...
# 8290  Wannabe analyst. General food enthusiast. Musi...
# 8291  Friendly pop cultureaholic. Analyst. Gamer. Am...
# 8292  Alcohol nerd. Award-winning music fan. Profess...
# 8293  Organizer. Introvert. Twitter junkie. Certifie...
# 8294  Unable to type with boxing gloves on. Devoted ...
#
#                              Movies  Religion                         Music  \
# 0     [Adventure, Action, Thriller]  Catholic        [Rock, Romantic, Jazz]
# 1                   [Drama, Action]  Agnostic               [Country, Jazz]
# 2               [Adventure, Comedy]    Muslim     [Classical, Country, Pop]
# 3                  [Horror, Action]  Agnostic              [Classical, Pop]
# 4                  [Action, Comedy]  Catholic          [EDM, Country, Jazz]
# ...                             ...       ...                           ...
# 8290            [Adventure, Action]  Agnostic        [Classical, Pop, Jazz]
# 8291             [Adventure, Drama]  Buddhist       [Romantic, HipHop, Pop]
# 8292             [Adventure, Drama]     Hindu  [HipHop, Classical, Country]
# 8293                [Drama, Action]     Hindu             [Rock, Jazz, EDM]
# 8294        [Horror, Drama, Comedy]    Muslim              [EDM, Classical]
#
#           Politics                   Social Media  \
# 0          Liberal  [Reddit, Facebook, Instagram]
# 1         Moderate                     [Facebook]
# 2          Liberal             [Youtube, Twitter]
# 3     Conservative  [Reddit, Facebook, Pinterest]
# 4         Moderate           [Facebook, LinkedIn]
# ...            ...                            ...
# 8290      Moderate  [Youtube, SnapChat, LinkedIn]
# 8291  Conservative                     [Facebook]
# 8292      Moderate            [Youtube, Facebook]
# 8293       Liberal            [Youtube, Facebook]
# 8294       Liberal            [Youtube, Facebook]
#
#                                         Sports                  Programming  \
# 0                             [Chess, Cricket]                 [JavaScript]
# 1                             [Chess, Cricket]                [C++, Python]
# 2       [Cricket, Baseball, BadmintonFootball]                    [C++, C#]
# 3                 [Cricket, BadmintonFootball]  [Swift, JavaScript, Python]
# 4     [Cricket, Basketball, BadmintonFootball]                  [Swift, Go]
# ...                                        ...                          ...
# 8290      [Chess, Baseball, BadmintonFootball]            [C++, Go, Python]
# 8291                [Cricket, Chess, Baseball]         [Swift, C++, Python]
# 8292              [Chess, Basketball, Cricket]           [Java, JavaScript]
# 8293      [Chess, Baseball, BadmintonFootball]   [Java, JavaScript, Python]
# 8294       [Cricket, Chess, BadmintonFootball]                  [Swift, C#]
#
#                                     Traveller  Age
# 0        [Adventure, Treking, Short journeys]   19
# 1            [Adventure, Treking, Long Trips]   19
# 2                        [Adventure, Treking]   23
# 3       [Treking, Long Trips, Short journeys]   28
# 4       [Treking, Long Trips, Short journeys]   19
# ...                                       ...  ...
# 8290              [Adventure, Short journeys]   23
# 8291                         [Short journeys]   23
# 8292  [Adventure, Long Trips, Short journeys]   34
# 8293                [Treking, Short journeys]   24
# 8294                             [Long Trips]   38
#
# [8295 rows x 10 columns]

# %% [markdown]
# ### Categorizing the religion and poilitics

# %%
df['Religion'] = pd.Categorical(df.Religion, ordered=True,
                                categories=['Catholic',
                                            'Christian',
                                            'Jewish',
                                            'Muslim',
                                            'Hindu',
                                            'Buddhist',
                                            'Spiritual',
                                            'Other',
                                            'Agnostic',
                                            'Atheist'])

df['Politics'] = pd.Categorical(df.Politics, ordered=True,
                                categories=['Liberal',
                                            'Progressive',
                                            'Centrist',
                                            'Moderate',
                                            'Conservative'])
# Out:
# C:\Users\aksha\AppData\Local\Temp/ipykernel_10020/1357384825.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Religion'] = pd.Categorical(df.Religion, ordered=True,
# C:\Users\aksha\AppData\Local\Temp/ipykernel_10020/1357384825.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Politics'] = pd.Categorical(df.Politics, ordered=True,

# %%
df
# Out:
#                                                    Bios  \
# 0     Typical communicator. Subtly charming web advo...
# 1     Introvert. Friendly beer guru. Bacon fanatic. ...
# 2     Friend of animals everywhere. Passionate zombi...
# 3     Webaholic. Pop culture ninja. Wannabe organize...
# 4     Zombie buff. Troublemaker. Social media ninja....
# ...                                                 ...
# 8290  Wannabe analyst. General food enthusiast. Musi...
# 8291  Friendly pop cultureaholic. Analyst. Gamer. Am...
# 8292  Alcohol nerd. Award-winning music fan. Profess...
# 8293  Organizer. Introvert. Twitter junkie. Certifie...
# 8294  Unable to type with boxing gloves on. Devoted ...
#
#                              Movies  Religion                         Music  \
# 0     [Adventure, Action, Thriller]  Catholic        [Rock, Romantic, Jazz]
# 1                   [Drama, Action]  Agnostic               [Country, Jazz]
# 2               [Adventure, Comedy]    Muslim     [Classical, Country, Pop]
# 3                  [Horror, Action]  Agnostic              [Classical, Pop]
# 4                  [Action, Comedy]  Catholic          [EDM, Country, Jazz]
# ...                             ...       ...                           ...
# 8290            [Adventure, Action]  Agnostic        [Classical, Pop, Jazz]
# 8291             [Adventure, Drama]  Buddhist       [Romantic, HipHop, Pop]
# 8292             [Adventure, Drama]     Hindu  [HipHop, Classical, Country]
# 8293                [Drama, Action]     Hindu             [Rock, Jazz, EDM]
# 8294        [Horror, Drama, Comedy]    Muslim              [EDM, Classical]
#
#           Politics                   Social Media  \
# 0          Liberal  [Reddit, Facebook, Instagram]
# 1         Moderate                     [Facebook]
# 2          Liberal             [Youtube, Twitter]
# 3     Conservative  [Reddit, Facebook, Pinterest]
# 4         Moderate           [Facebook, LinkedIn]
# ...            ...                            ...
# 8290      Moderate  [Youtube, SnapChat, LinkedIn]
# 8291  Conservative                     [Facebook]
# 8292      Moderate            [Youtube, Facebook]
# 8293       Liberal            [Youtube, Facebook]
# 8294       Liberal            [Youtube, Facebook]
#
#                                         Sports                  Programming  \
# 0                             [Chess, Cricket]                 [JavaScript]
# 1                             [Chess, Cricket]                [C++, Python]
# 2       [Cricket, Baseball, BadmintonFootball]                    [C++, C#]
# 3                 [Cricket, BadmintonFootball]  [Swift, JavaScript, Python]
# 4     [Cricket, Basketball, BadmintonFootball]                  [Swift, Go]
# ...                                        ...                          ...
# 8290      [Chess, Baseball, BadmintonFootball]            [C++, Go, Python]
# 8291                [Cricket, Chess, Baseball]         [Swift, C++, Python]
# 8292              [Chess, Basketball, Cricket]           [Java, JavaScript]
# 8293      [Chess, Baseball, BadmintonFootball]   [Java, JavaScript, Python]
# 8294       [Cricket, Chess, BadmintonFootball]                  [Swift, C#]
#
#                                     Traveller  Age
# 0        [Adventure, Treking, Short journeys]   19
# 1            [Adventure, Treking, Long Trips]   19
# 2                        [Adventure, Treking]   23
# 3       [Treking, Long Trips, Short journeys]   28
# 4       [Treking, Long Trips, Short journeys]   19
# ...                                       ...  ...
# 8290              [Adventure, Short journeys]   23
# 8291                         [Short journeys]   23
# 8292  [Adventure, Long Trips, Short journeys]   34
# 8293                [Treking, Short journeys]   24
# 8294                             [Long Trips]   38
#
# [8295 rows x 10 columns]

# %% [markdown]
# ### Saving and exporting the pickle file

# %%
with open("refined_profiles.pkl",'wb') as fp:
    pickle.dump(df, fp)
